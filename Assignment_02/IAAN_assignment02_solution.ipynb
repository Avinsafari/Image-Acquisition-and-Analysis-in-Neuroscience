# %% [markdown]
# # Exercise 2

# %%
from PIL import Image
from IPython.display import display
img = Image.open('IAAN_A2_Ex2a.jpeg')
display(img,)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1282x1600>

# %%
img = Image.open('IAAN_A2_Ex2b.jpeg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x724>
